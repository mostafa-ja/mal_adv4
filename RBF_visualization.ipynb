# %% [markdown]
# <a href="https://colab.research.google.com/github/mostafa-ja/mal_adv4/blob/main/RBF_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the kernels and their derivatives
def gaussian_rbf(x, c, sigma):
    return np.exp(-np.square(x - c) / (2 * sigma**2))

def gaussian_rbf_derivative(x, c, sigma):
    return gaussian_rbf(x, c, sigma) * (-(x - c) / sigma**2)

def laplacian_rbf(x, c, sigma):
    return np.exp(-np.abs(x - c) / sigma)

def laplacian_rbf_derivative(x, c, sigma):
    return laplacian_rbf(x, c, sigma) * (-np.sign(x - c) / sigma)

# Parameters
x = np.linspace(-6, 6, 200)  # Input range
c = 0  # Center
sigma = 4.  # Spread

# Calculate the kernel values and their derivatives
gaussian_values = gaussian_rbf(x, c, sigma)
gaussian_derivative_values = gaussian_rbf_derivative(x, c, sigma)
laplacian_values = laplacian_rbf(x, c, sigma)
laplacian_derivative_values = laplacian_rbf_derivative(x, c, sigma)

# Plot the kernels
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.plot(x, gaussian_values, label='Gaussian RBF', color='blue')
plt.plot(x, laplacian_values, label='Laplacian RBF', color='red', linestyle='--')
plt.title('Gaussian vs. Laplacian Radial Basis Function Kernels')
plt.xlabel('x')
plt.ylabel('Kernel value')
plt.legend()
plt.grid(True)

# Plot the derivatives
plt.subplot(1, 2, 2)
plt.plot(x, gaussian_derivative_values, label='Gaussian RBF Derivative', color='blue')
plt.plot(x, laplacian_derivative_values, label='Laplacian RBF Derivative', color='red', linestyle='--')
plt.title('Derivatives of Gaussian and Laplacian RBF Kernels')
plt.xlabel('x')
plt.ylabel('Derivative value')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Step 1: Install gdown
# !pip install gdown

# Step 2: Define the Google Drive file ID and download path
file_id = '1hYbGvflzRC_V0yvCXYgqqdWlBuiMy3xC'  # Replace with your file ID
file_id2 = '1GtxjkZ_KJvLTxBdif5sJk7viqCd_4mot'
output_path = 'model.pth'

# Step 3: Download the file using gdown
import gdown

# Construct the full URL for the file
url = f'https://drive.google.com/uc?id={file_id}'
url2 = f'https://drive.google.com/uc?id={file_id2}'
# Download the file
gdown.download(url, output_path, quiet=False)
gdown.download(url2, quiet=False)
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.1.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.14.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.2.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Downloading...
# From (original): https://drive.google.com/uc?id=1hYbGvflzRC_V0yvCXYgqqdWlBuiMy3xC
# From (redirected): https://drive.google.com/uc?id=1hYbGvflzRC_V0yvCXYgqqdWlBuiMy3xC&confirm=t&uuid=cf247eea-7338-454f-8b0c-6ef2910cfe65
# To: /content/model.pth
# 100%|██████████| 80.0M/80.0M [00:01<00:00, 49.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1GtxjkZ_KJvLTxBdif5sJk7viqCd_4mot
# To: /content/all_centers.npy
# 100%|██████████| 80.0M/80.0M [00:01<00:00, 72.5MB/s]
# 'all_centers.npy'

# %%
download_links = ['https://github.com/mostafa-ja/mal_adv3/raw/main/drebin/sparse_matrix_0.npz',
                  'https://github.com/mostafa-ja/mal_adv3/raw/main/drebin/sparse_matrix_1.npz',
                  'https://github.com/mostafa-ja/mal_adv3/raw/main/drebin/sparse_matrix_2.npz',
                  'https://github.com/mostafa-ja/mal_adv3/raw/main/drebin/sparse_matrix_y0.npz',
                  'https://github.com/mostafa-ja/mal_adv3/raw/main/drebin/sparse_matrix_y1.npz',
                  'https://github.com/mostafa-ja/mal_adv3/raw/main/drebin/sparse_matrix_y2.npz',
                  'https://github.com/mostafa-ja/mal_adv4/raw/main/dataset/insertion_array.pkl',
                  'https://github.com/mostafa-ja/mal_adv4/raw/main/dataset/removal_array.pkl',
                  'https://github.com/mostafa-ja/mal_adv4/raw/main/dataset/adverserial_attacks_functions.py'
]

# %%
import gdown
output_filepath = '/content/'
for link in download_links:
  gdown.download(link, output_filepath)
# Out:
# Downloading...
# From: https://github.com/mostafa-ja/mal_adv3/raw/main/drebin/sparse_matrix_0.npz
# To: /content/sparse_matrix_0.npz
# 100%|██████████| 461k/461k [00:00<00:00, 7.06MB/s]
# Downloading...
# From: https://github.com/mostafa-ja/mal_adv3/raw/main/drebin/sparse_matrix_1.npz
# To: /content/sparse_matrix_1.npz
# 100%|██████████| 148k/148k [00:00<00:00, 6.78MB/s]
# Downloading...
# From: https://github.com/mostafa-ja/mal_adv3/raw/main/drebin/sparse_matrix_2.npz
# To: /content/sparse_matrix_2.npz
# 100%|██████████| 150k/150k [00:00<00:00, 5.49MB/s]
# Downloading...
# From: https://github.com/mostafa-ja/mal_adv3/raw/main/drebin/sparse_matrix_y0.npz
# To: /content/sparse_matrix_y0.npz
# 100%|██████████| 5.79k/5.79k [00:00<00:00, 10.3MB/s]
# Downloading...
# From: https://github.com/mostafa-ja/mal_adv3/raw/main/drebin/sparse_matrix_y1.npz
# To: /content/sparse_matrix_y1.npz
# 100%|██████████| 2.64k/2.64k [00:00<00:00, 2.99MB/s]
# Downloading...
# From: https://github.com/mostafa-ja/mal_adv3/raw/main/drebin/sparse_matrix_y2.npz
# To: /content/sparse_matrix_y2.npz
# 100%|██████████| 2.71k/2.71k [00:00<00:00, 7.30MB/s]
# Downloading...
# From: https://github.com/mostafa-ja/mal_adv4/raw/main/dataset/insertion_array.pkl
# To: /content/insertion_array.pkl
# 100%|██████████| 80.2k/80.2k [00:00<00:00, 3.41MB/s]
# Downloading...
# From: https://github.com/mostafa-ja/mal_adv4/raw/main/dataset/removal_array.pkl
# To: /content/removal_array.pkl
# 100%|██████████| 80.2k/80.2k [00:00<00:00, 4.58MB/s]
# Downloading...
# From: https://github.com/mostafa-ja/mal_adv4/raw/main/dataset/adverserial_attacks_functions.py
# To: /content/adverserial_attacks_functions.py
# 67.1kB [00:00, 50.9MB/s]

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,balanced_accuracy_score
import numpy as np
from scipy import sparse
import matplotlib.pyplot as plt
import pickle
import random
import time

# Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

from adverserial_attacks_functions import *


torch.manual_seed(0)
# Out:
# cpu
# cpu

# %%
# Open the .pkl file
with open('/content/insertion_array.pkl', 'rb') as f:
    # Load the object
    insertion_array = pickle.load(f)

# Close the file
f.close()

insertion_array = torch.tensor(insertion_array).to(device)
print(len(insertion_array))

# Open the .pkl file
with open('/content/removal_array.pkl', 'rb') as f:
    # Load the object
    removal_array = pickle.load(f)

# Close the file
f.close()

removal_array = torch.tensor(removal_array).to(device)
print(len(removal_array))
# Out:
# 10000
# 10000

# %%
# Load dataset
X_train = sparse.load_npz("/content/sparse_matrix_0.npz").toarray()
X_val = sparse.load_npz("/content/sparse_matrix_1.npz").toarray()
X_test = sparse.load_npz("/content/sparse_matrix_2.npz").toarray()

X_train = torch.tensor(X_train, dtype=torch.int8)
X_val = torch.tensor(X_val, dtype=torch.int8)
X_test = torch.tensor(X_test, dtype=torch.int8)


y_train = sparse.load_npz("/content/sparse_matrix_y0.npz").toarray().reshape((-1, 1))
y_val = sparse.load_npz("/content/sparse_matrix_y1.npz").toarray().reshape((-1, 1))
y_test = sparse.load_npz("/content/sparse_matrix_y2.npz").toarray().reshape((-1, 1))

y_train = torch.tensor(y_train, dtype=torch.int8)
y_val = torch.tensor(y_val, dtype=torch.int8)
y_test = torch.tensor(y_test, dtype=torch.int8)


print("Shapes:")
print("x_train:", X_train.shape)
print("x_val:", X_val.shape)
print("x_test:", X_test.shape)
print("y_train:", y_train.shape)
print("y_val:", y_val.shape)
print("y_test:", y_test.shape)
# Out:
# Shapes:
# x_train: torch.Size([28683, 10000])
# x_val: torch.Size([9562, 10000])
# x_test: torch.Size([9562, 10000])
# y_train: torch.Size([28683, 1])
# y_val: torch.Size([9562, 1])
# y_test: torch.Size([9562, 1])

# %%
# number of benigns and malicious sample in training dataset
n_ben = (y_train.squeeze()== 0).sum().item()
n_mal = (y_train.squeeze()== 1).sum().item()
print('the proportion of malwares : ', n_mal/(n_mal+n_ben))

# Combine features and labels into datasets
train_dataset = TensorDataset(X_train, y_train)
val_dataset = TensorDataset(X_val, y_val)
test_dataset = TensorDataset(X_test, y_test)

# Define the DataLoader for training, validation, and test sets
batch_size = 128 #32
train_loader = DataLoader(train_dataset, batch_size=batch_size,shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Clear unnecessary variables
del train_dataset, val_dataset, test_dataset, y_train, y_val, y_test
# Out:
# the proportion of malwares :  0.11386535578565701

# %%
# Load the array from the file
all_centers = np.load('all_centers.npy')

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import numpy as np
from sklearn.cluster import KMeans

# Define the RBF model
class RBFModel(nn.Module):
    def __init__(self, hidden_dim, output_dim, init_centers, init_sigmas, kernel):
        super(RBFModel, self).__init__()
        self.hidden_dim = hidden_dim
        self.centers = nn.Parameter(torch.Tensor(init_centers))
        self.sigmas = nn.Parameter(torch.Tensor(init_sigmas))
        self.kernel = kernel
        # Linear layer for output
        self.linear = nn.Linear(hidden_dim, output_dim)

    def gaussian(self, x, c, sigma):
        return torch.exp(-torch.sum((x[:, None, :] - c) ** 2, dim=-1) / (2 * sigma ** 2))

    def laplacian(self, x, c, sigma):
        return torch.exp(-torch.sum(torch.abs(x[:, None, :] - c) , dim=-1) / sigma)

    def forward(self, x):
      if self.kernel == 'gaussian':
        radial_out = self.gaussian(x, self.centers, self.sigmas)
      elif self.kernel == 'laplacian':
        radial_out = self.laplacian(x, self.centers, self.sigmas)
      else:
        raise ValueError("Invalid kernel type. Choose 'gaussian' or 'laplacian'.")

      output = self.linear(radial_out.to(torch.float32))
      return output

# Function to evaluate the model on a dataset
def evaluate_model(model, data_loader, criterion, removal_array = removal_array, non_removal_features = False):
    model.eval()
    total_loss = 0.0
    correct_predictions = 0
    non_removal_mask = torch.logical_not(removal_array).to('cpu')

    with torch.no_grad():
        for batch_x, batch_y in data_loader:
            if non_removal_features:
                batch_x, batch_y = batch_x[:,non_removal_mask].to(torch.float32).to(device), batch_y.to(device)  # Move data to GPU
            else:
                batch_x, batch_y = batch_x.to(torch.float32).to(device), batch_y.to(device)  # Move data to GPU
            output = model(batch_x)
            loss = criterion(output, batch_y.squeeze().to(torch.long))
            total_loss += loss.item()
            _, predicted = torch.max(output, 1)
            correct_predictions += (predicted == batch_y.squeeze()).sum().item()

    avg_loss = total_loss / len(data_loader)
    accuracy = correct_predictions / len(data_loader.dataset)

    return avg_loss, accuracy

# %%
non_removal_features = False
non_removal_mask = torch.logical_not(removal_array).to('cpu')
sigma = 4.15
kernel = 'gaussian'
#all_centers = torch.rand((1000, 10000))
model = RBFModel(1000, 2, all_centers, [sigma], kernel)
model = model.to(device)

# Load the model state dictionary
model.load_state_dict(torch.load('/content/model.pth', map_location=torch.device(device)))
# Out:
# <All keys matched successfully>

# %%
# Step 1: Initialize centers and sigmas
all_centers2 = model.centers.detach()
all_centers2.shape
# Out:
# torch.Size([1000, 10000])

# %%
all_data = torch.cat([batch for batch, _ in train_loader], dim=0)
labels = torch.cat([label.squeeze() for _, label in train_loader], dim=0)
print(all_data.shape)
print(labels.shape)
# Out:
# torch.Size([28683, 10000])
# torch.Size([28683])

# %%
from sklearn.manifold import TSNE

# Assuming X contains your features and y contains your labels
# X.shape = (number of samples, number of features)
# y.shape = (number of samples,)
tsne = TSNE(n_components=2, random_state=42)
X_embedded = tsne.fit_transform(all_data[:5000])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot with Seaborn
sns.scatterplot(x=X_embedded[:5000, 0], y=X_embedded[:5000, 1], hue=labels[:5000], palette=['b', 'r'], alpha=0.7)
plt.xlabel('t-SNE Dimension 1')
plt.ylabel('t-SNE Dimension 2')
plt.title('t-SNE Visualization of Malware vs Benign Samples')
plt.legend(title='Label', loc='upper right', labels=['Benign', 'Malware'])
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# Assuming X is your original high-dimensional data
# Assuming labels is your array of labels
# Assuming centers is a numpy array of shape (1000, original_dim) representing the 1000 high-dimensional centers

# Combine original data and centers for t-SNE transformation
combined_data = np.vstack([all_data[:10000], all_centers,all_centers2])

# Apply t-SNE to the combined data
tsne = TSNE(n_components=2, random_state=42)
X_embedded_combined = tsne.fit_transform(combined_data)

# %%
# Extract the embedded data and centers
X_embedded = X_embedded_combined[:10000]  # Original data points
centers_embedded = X_embedded_combined[10000:10500]  # Centers
centers_embedded2 = X_embedded_combined[10500:11000]  # Centers
centers_embedded3 = X_embedded_combined[11000:11500]  # Centers
centers_embedded4 = X_embedded_combined[11500:12000]  # Centers

# %%
# Create a larger plot
plt.figure(figsize=(12, 8))

# Plot with Seaborn
# First, plot the data points
#scatter = sns.scatterplot(x=X_embedded[:, 0], y=X_embedded[:, 1], hue=labels[:10000], palette=['b', 'r'], alpha=0.7, marker='o')

# Then, plot the first set of centers
plt.scatter(centers_embedded[:, 0], centers_embedded[:, 1], alpha=0.5, marker='x', s=100, c='black', label='Centers 1')

# Plot the second set of centers
plt.scatter(centers_embedded2[:, 0], centers_embedded2[:, 1], alpha=0.5, marker='x', s=100, c='green', label='Centers 2')

# Then, plot the first set of centers
plt.scatter(centers_embedded3[:, 0], centers_embedded3[:, 1], alpha=0.7, marker='*', s=50, c='cyan', label='Centers 3')

# Plot the second set of centers
plt.scatter(centers_embedded4[:, 0], centers_embedded4[:, 1], alpha=0.7, marker='*', s=50, c='pink', label='Centers 4')

# Customize legend
plt.legend(title='Legend', loc='upper right')
plt.xlabel('t-SNE Dimension 1')
plt.ylabel('t-SNE Dimension 2')
plt.title('t-SNE Visualization of Data and Centers')
plt.show()

# %%
for x,y in test_loader:
  benigns = x[y.squeeze()== 0]
  malwares = x[y.squeeze()== 1]
  print(benigns.shape)
  print(malwares.shape)
  break
# Out:
# torch.Size([113, 10000])
# torch.Size([15, 10000])

# %%
radial_out = model.gaussian(benigns, model.centers, model.sigmas)

# %%
radial_out.shape
# Out:
# torch.Size([113, 1000])

# %%
radial_out[0]
# Out:
# tensor([2.8917e-01, 2.7569e-01, 3.7178e-01, 2.7866e-01, 2.6661e-01, 2.7944e-01,
#         2.4790e-01, 2.6938e-01, 2.6300e-01, 1.0859e-01, 2.7399e-01, 1.4636e-01,
#         1.2663e-01, 1.7378e-01, 2.1876e-01, 7.7104e-02, 1.6826e-01, 1.8220e-01,
#         2.7356e-01, 2.9880e-01, 1.8468e-01, 9.6225e-05, 1.6634e-01, 1.8489e-01,
#         2.6314e-01, 2.7594e-01, 9.7580e-02, 2.7296e-01, 9.1946e-03, 1.8464e-01,
#         2.0534e-01, 3.0841e-01, 1.3968e-01, 1.3436e-01, 2.3451e-01, 2.9428e-01,
#         3.0741e-01, 1.8587e-01, 1.8787e-01, 2.6046e-01, 1.9053e-01, 3.1529e-01,
#         1.7558e-01, 2.5896e-01, 2.0780e-01, 1.6056e-04, 2.6589e-01, 1.8531e-01,
#         1.1723e-01, 8.1942e-02, 2.0258e-01, 1.1829e-01, 2.0684e-01, 2.9928e-01,
#         1.6573e-01, 3.6237e-01, 1.7767e-01, 7.3258e-02, 2.6108e-01, 1.5196e-01,
#         2.8353e-01, 1.9153e-01, 3.3570e-02, 6.2416e-02, 2.5720e-01, 4.4820e-02,
#         1.6643e-01, 2.9284e-01, 1.2248e-04, 1.9055e-01, 1.1620e-01, 5.0027e-01,
#         3.0327e-01, 2.3228e-01, 1.4606e-01, 2.5504e-01, 1.4072e-01, 2.6725e-01,
#         1.3326e-01, 1.4751e-01, 4.6965e-02, 2.0549e-04, 2.6958e-01, 2.6358e-01,
#         1.2878e-01, 2.3583e-01, 2.0371e-01, 2.7973e-01, 1.4802e-04, 1.3628e-04,
#         1.1559e-01, 2.9023e-01, 2.0707e-01, 2.3433e-01, 2.6446e-01, 2.6990e-01,
#         2.7750e-01, 2.0998e-01, 2.9507e-02, 1.5023e-01, 2.9461e-01, 1.1591e-04,
#         1.9346e-01, 9.5791e-05, 1.5164e-01, 1.6322e-01, 2.1634e-01, 1.1832e-04,
#         1.9643e-01, 4.4588e-04, 1.3061e-01, 5.0940e-02, 1.3297e-01, 1.7356e-01,
#         8.8403e-02, 1.8160e-01, 1.9665e-01, 1.6977e-01, 2.6941e-01, 1.5239e-01,
#         2.0220e-01, 3.2250e-01, 1.5509e-01, 2.1783e-01, 2.6652e-01, 2.1726e-01,
#         1.5382e-01, 1.3096e-01, 2.8108e-01, 2.7486e-01, 4.6832e-03, 1.2194e-01,
#         2.7475e-01, 2.2528e-01, 2.9311e-01, 2.8524e-01, 2.4054e-01, 1.2841e-01,
#         2.8143e-01, 2.0651e-01, 2.0247e-01, 2.4117e-01, 2.6229e-01, 1.5580e-01,
#         2.0457e-01, 2.7284e-01, 2.6953e-01, 3.0028e-01, 2.5823e-01, 1.7542e-01,
#         9.2915e-02, 2.6157e-01, 1.9998e-01, 2.8069e-01, 2.3816e-01, 2.8766e-01,
#         2.1702e-01, 1.3761e-01, 7.6989e-02, 1.1339e-01, 2.8599e-01, 1.7409e-01,
#         1.9052e-01, 1.9567e-01, 3.0681e-01, 2.1643e-01, 2.1213e-01, 2.5877e-01,
#         2.4190e-01, 2.7628e-01, 2.5938e-01, 2.1055e-01, 2.4981e-01, 2.3518e-01,
#         2.2957e-01, 2.1408e-04, 3.6639e-01, 2.7379e-01, 1.5704e-01, 3.5902e-01,
#         3.1058e-01, 2.0552e-01, 2.5805e-01, 2.1495e-01, 1.6860e-01, 2.1961e-01,
#         2.0542e-01, 2.4537e-04, 2.1511e-01, 2.6996e-01, 1.4419e-01, 3.0753e-04,
#         2.9596e-01, 1.6604e-01, 3.4010e-01, 4.9145e-02, 1.6097e-01, 1.7497e-01,
#         2.4766e-01, 2.4260e-01, 2.6098e-01, 2.3842e-01, 1.7795e-01, 2.9585e-01,
#         1.5233e-01, 6.6762e-02, 1.5307e-01, 2.6889e-01, 1.1091e-01, 8.5541e-02,
#         2.5690e-01, 2.6916e-04, 1.9097e-01, 6.9321e-03, 2.5361e-01, 1.5113e-01,
#         1.5002e-01, 1.9400e-01, 1.9601e-01, 2.3320e-01, 2.2339e-01, 2.7205e-01,
#         1.1165e-04, 1.6833e-01, 3.5268e-01, 1.9377e-01, 6.1922e-02, 2.2779e-01,
#         2.5279e-01, 1.8071e-01, 1.5846e-01, 2.0191e-01, 1.1445e-01, 2.8740e-01,
#         1.6707e-01, 3.2059e-01, 2.1767e-01, 2.6895e-01, 5.2532e-02, 2.5006e-01,
#         1.8499e-01, 1.7299e-01, 1.1946e-04, 2.1142e-01, 1.2246e-01, 2.2026e-01,
#         1.0650e-01, 1.6335e-04, 1.5720e-01, 2.6556e-01, 2.8396e-01, 2.5380e-01,
#         2.7480e-01, 2.3543e-01, 1.9783e-01, 2.5174e-01, 2.3144e-01, 1.2568e-04,
#         2.6310e-01, 1.8515e-01, 7.4957e-02, 3.6682e-01, 1.0745e-01, 1.7968e-01,
#         2.0824e-01, 1.9553e-01, 2.7745e-01, 1.3464e-04, 1.8158e-01, 1.9888e-01,
#         2.5011e-01, 2.3825e-01, 1.5758e-01, 8.0878e-02, 1.5359e-04, 1.6740e-01,
#         2.4210e-01, 2.4140e-01, 2.8251e-02, 2.7153e-01, 1.3631e-01, 1.4494e-04,
#         2.3036e-01, 1.8333e-01, 3.2633e-01, 2.9715e-01, 1.7063e-01, 1.7353e-04,
#         2.5859e-01, 1.8279e-01, 1.7276e-01, 2.7533e-01, 2.6684e-01, 1.2590e-04,
#         1.1102e-01, 9.9603e-05, 2.5249e-01, 2.8614e-01, 1.9398e-01, 2.5700e-01,
#         2.2140e-01, 1.3158e-01, 1.7181e-01, 1.4221e-01, 1.8844e-01, 1.3856e-01,
#         3.2826e-01, 1.7934e-01, 1.5795e-01, 2.3496e-01, 3.3433e-01, 1.8718e-01,
#         1.5231e-01, 2.8442e-01, 2.2612e-01, 3.0193e-01, 2.2405e-01, 2.0505e-04,
#         2.5928e-01, 1.6691e-01, 8.3872e-02, 9.2610e-05, 2.8168e-01, 2.6056e-01,
#         2.6775e-01, 3.1384e-01, 1.9708e-01, 2.4792e-01, 2.2462e-01, 1.0724e-04,
#         2.5173e-01, 2.8310e-01, 6.8100e-02, 1.3373e-01, 2.5281e-01, 2.3444e-01,
#         3.9783e-04, 1.2354e-01, 2.4196e-01, 2.7253e-01, 2.1162e-01, 2.0293e-01,
#         2.7909e-01, 1.6642e-01, 1.3710e-01, 3.4892e-01, 1.3768e-01, 2.5815e-01,
#         2.7225e-01, 2.2559e-01, 1.7864e-01, 2.9417e-01, 1.9700e-01, 3.0841e-01,
#         1.9714e-01, 2.0390e-01, 2.6704e-01, 1.8150e-01, 1.7888e-01, 1.7960e-01,
#         1.7121e-01, 1.3251e-01, 2.4413e-01, 1.2972e-01, 1.3060e-01, 3.3415e-02,
#         1.6915e-01, 1.0903e-04, 2.2397e-01, 4.6863e-04, 2.8904e-01, 1.7349e-01,
#         2.2305e-01, 1.4322e-01, 1.9252e-01, 2.7047e-01, 2.4759e-01, 1.2830e-01,
#         2.3609e-01, 2.9600e-01, 2.0871e-01, 1.1298e-01, 2.6851e-01, 2.6941e-01,
#         1.7508e-01, 1.6170e-01, 1.8031e-01, 2.6444e-01, 1.7157e-01, 2.5779e-01,
#         1.9631e-01, 2.9823e-01, 2.5500e-01, 1.9225e-01, 1.3077e-01, 2.3274e-01,
#         9.7182e-02, 1.8075e-01, 8.0973e-02, 1.6658e-01, 2.7539e-01, 1.6100e-01,
#         2.4322e-01, 2.3821e-01, 2.8601e-01, 2.4403e-01, 2.3340e-01, 1.4986e-01,
#         2.1076e-01, 1.7396e-01, 2.2756e-01, 3.1143e-01, 2.9182e-01, 1.2581e-04,
#         2.7166e-01, 2.1992e-01, 2.4904e-01, 2.1483e-01, 2.7401e-01, 2.8466e-01,
#         2.3571e-01, 2.3128e-01, 3.1694e-01, 2.2072e-01, 9.1041e-02, 1.6521e-01,
#         1.9598e-01, 3.6926e-01, 9.8873e-04, 1.9932e-01, 1.4939e-01, 1.1322e-03,
#         2.1293e-01, 2.5669e-01, 2.6787e-01, 5.2446e-02, 2.7821e-01, 2.6122e-01,
#         8.0997e-02, 2.6076e-01, 2.4719e-01, 2.7656e-01, 2.3881e-01, 3.2527e-01,
#         2.8876e-01, 3.2989e-02, 1.1515e-03, 3.2492e-02, 1.5301e-01, 2.4998e-01,
#         2.7171e-04, 2.8476e-01, 1.0087e-01, 1.0632e-01, 1.3733e-01, 1.2437e-04,
#         2.8402e-01, 1.8272e-01, 2.2483e-01, 3.2443e-01, 9.6379e-02, 2.4544e-01,
#         1.9131e-01, 2.0596e-01, 2.1504e-01, 6.3038e-04, 6.1607e-02, 2.5424e-01,
#         2.4096e-01, 1.9119e-01, 2.3872e-01, 2.1825e-01, 1.5106e-01, 2.3142e-01,
#         2.6136e-01, 1.4139e-01, 2.3886e-01, 1.2971e-01, 2.7914e-01, 2.9766e-02,
#         2.0185e-01, 1.5515e-01, 1.3706e-01, 1.9123e-01, 2.1142e-01, 2.3346e-01,
#         2.0022e-01, 7.4425e-04, 1.8891e-01, 1.5437e-01, 2.5395e-01, 3.4539e-01,
#         2.3799e-01, 1.7090e-01, 1.6250e-01, 1.7052e-01, 2.2471e-01, 1.9031e-01,
#         2.7337e-01, 2.7448e-01, 2.3568e-01, 2.6804e-01, 2.2548e-01, 3.0414e-01,
#         3.4181e-01, 2.8354e-01, 2.6263e-01, 1.8111e-01, 1.4676e-01, 2.6475e-01,
#         1.7502e-01, 1.0197e-04, 2.4825e-01, 2.4028e-01, 1.8540e-01, 2.8146e-01,
#         7.8364e-02, 1.3376e-01, 2.9657e-01, 3.6934e-01, 2.6888e-01, 9.9941e-05,
#         3.2406e-01, 2.8997e-01, 2.6410e-01, 4.7888e-01, 2.7874e-01, 2.8484e-01,
#         2.9896e-01, 1.6196e-01, 1.9384e-01, 2.1568e-01, 2.8311e-01, 1.5551e-01,
#         1.4931e-01, 2.3827e-01, 2.5453e-01, 2.0423e-01, 9.4956e-02, 7.7277e-02,
#         6.5223e-02, 2.6214e-01, 1.6787e-01, 2.8441e-01, 2.9527e-01, 1.5760e-01,
#         1.5737e-01, 2.1929e-01, 1.3083e-01, 2.9120e-01, 2.0113e-02, 1.4522e-01,
#         2.7934e-01, 1.9658e-01, 2.6944e-01, 1.8114e-01, 2.7702e-01, 6.1969e-02,
#         1.9414e-01, 6.7085e-03, 2.8776e-01, 1.5255e-04, 1.3210e-01, 2.9144e-01,
#         2.7818e-01, 2.3979e-01, 1.9022e-01, 2.5829e-01, 1.8347e-01, 8.8577e-02,
#         9.3840e-05, 1.1832e-02, 2.2708e-04, 2.0128e-01, 3.2702e-01, 9.0737e-02,
#         1.8282e-01, 3.0799e-01, 1.3159e-01, 1.8387e-01, 1.4946e-01, 2.8331e-01,
#         1.5189e-01, 2.6492e-01, 1.5330e-01, 1.4963e-01, 2.8573e-01, 1.3729e-01,
#         1.5819e-01, 2.6980e-01, 2.6571e-01, 1.6492e-01, 1.5388e-01, 2.3813e-01,
#         1.6717e-01, 1.7070e-01, 1.6941e-01, 9.6996e-02, 1.6629e-01, 1.3429e-01,
#         5.9688e-02, 1.4847e-01, 1.4956e-01, 1.6300e-01, 3.6577e-02, 7.6472e-05,
#         2.0137e-01, 1.4885e-02, 2.9994e-01, 2.1988e-01, 2.0493e-01, 7.8932e-02,
#         2.7189e-01, 1.0557e-01, 1.7631e-01, 3.3469e-01, 9.1109e-02, 1.3965e-01,
#         1.7129e-01, 1.4038e-01, 2.2135e-01, 2.8032e-04, 2.8742e-01, 2.0130e-01,
#         2.8004e-01, 2.9265e-01, 1.0064e-01, 2.5677e-01, 2.9495e-01, 2.8918e-04,
#         2.9184e-01, 2.7062e-01, 1.8235e-01, 3.2497e-01, 7.2876e-02, 1.4994e-01,
#         8.7416e-02, 2.6383e-01, 7.0578e-02, 2.2187e-01, 1.0463e-01, 1.8418e-01,
#         2.8045e-01, 2.2595e-01, 1.8217e-01, 2.0163e-01, 2.5931e-01, 1.2157e-01,
#         1.5560e-01, 1.0618e-01, 2.4001e-01, 2.3382e-01, 1.8386e-01, 2.4140e-01,
#         1.7987e-01, 2.7039e-01, 1.0208e-01, 2.3598e-01, 1.3132e-01, 1.5914e-01,
#         9.5384e-02, 2.2816e-01, 1.9785e-01, 2.1543e-01, 1.3532e-01, 1.3927e-01,
#         2.8376e-01, 2.1642e-01, 2.2303e-01, 1.8725e-01, 1.4836e-01, 1.9959e-01,
#         3.7828e-04, 1.7494e-01, 2.0990e-01, 2.1891e-03, 1.4760e-01, 1.5711e-01,
#         1.1683e-01, 2.7873e-01, 1.1924e-01, 2.1011e-01, 1.7713e-01, 1.9176e-01,
#         1.6359e-01, 1.7489e-01, 1.8721e-01, 1.5483e-01, 1.5534e-01, 1.6698e-01,
#         7.2157e-02, 1.5104e-01, 1.5069e-02, 3.0980e-01, 2.2096e-01, 8.8723e-02,
#         1.1984e-01, 1.7906e-01, 1.8018e-01, 2.1019e-01, 1.6535e-01, 1.1480e-01,
#         5.1799e-02, 2.8907e-01, 2.9708e-01, 1.2560e-01, 1.5757e-01, 1.9441e-01,
#         1.7467e-01, 7.8856e-02, 1.4979e-01, 2.0549e-01, 1.6116e-01, 1.3605e-01,
#         1.1842e-04, 7.4562e-02, 2.0513e-01, 2.8074e-01, 7.6979e-04, 2.4565e-01,
#         2.3475e-01, 1.0702e-01, 2.4799e-01, 6.1069e-02, 1.0278e-01, 1.0830e-01,
#         1.4197e-04, 1.8267e-01, 1.8321e-01, 1.9160e-01, 1.7386e-01, 1.3959e-01,
#         2.2059e-01, 2.2364e-04, 1.7002e-04, 1.5836e-01, 1.9539e-01, 2.7741e-01,
#         1.9403e-01, 5.0168e-02, 1.1190e-01, 2.7150e-04, 1.6122e-01, 2.2655e-01,
#         2.3489e-01, 2.6854e-01, 1.7185e-01, 1.6678e-01, 2.2969e-01, 2.7399e-01,
#         1.9867e-01, 1.7512e-04, 2.3447e-01, 1.5087e-01, 2.1328e-01, 2.4648e-01,
#         9.0453e-02, 3.1724e-01, 2.6699e-01, 3.0617e-01, 1.5212e-01, 1.5297e-01,
#         2.0977e-01, 2.3580e-01, 1.2962e-04, 1.5599e-01, 2.9576e-01, 1.6712e-01,
#         1.4534e-01, 1.5769e-01, 1.7931e-01, 1.3097e-01, 2.4299e-01, 2.4424e-01,
#         1.5701e-01, 1.3233e-01, 2.5098e-01, 2.4604e-01, 1.5599e-01, 1.2079e-01,
#         1.5092e-01, 2.2812e-01, 1.2884e-01, 3.3484e-01, 1.5300e-01, 1.7484e-01,
#         2.0986e-01, 6.9934e-02, 2.1246e-01, 2.6383e-01, 2.9175e-01, 2.5870e-01,
#         2.1009e-01, 6.1792e-03, 1.8801e-01, 1.5122e-01, 1.7734e-01, 1.8492e-01,
#         2.8663e-01, 2.2416e-01, 1.8305e-01, 9.1555e-02, 1.8126e-01, 2.0049e-01,
#         2.4152e-01, 2.5545e-01, 2.4246e-01, 1.9029e-01, 3.2169e-01, 1.8215e-01,
#         3.2532e-03, 2.1835e-01, 1.9364e-01, 2.7412e-01, 1.4806e-01, 2.8139e-01,
#         2.5084e-01, 1.7204e-01, 1.5869e-01, 2.4664e-01, 2.5468e-01, 2.7718e-01,
#         2.5066e-01, 1.7100e-01, 1.3369e-01, 2.6468e-01, 2.9490e-03, 1.8636e-01,
#         1.8148e-01, 1.5055e-01, 1.5234e-04, 2.9104e-01, 1.2969e-01, 1.1732e-01,
#         1.7927e-01, 2.2850e-01, 1.5451e-01, 1.7155e-01, 1.6292e-01, 1.2992e-01,
#         2.2205e-01, 2.1432e-01, 1.1643e-01, 1.8729e-01, 9.6374e-02, 1.8815e-01,
#         1.8822e-01, 1.8772e-01, 1.2534e-01, 1.5149e-01, 2.8092e-01, 1.5929e-01,
#         2.5060e-01, 1.2149e-01, 2.2638e-01, 1.9090e-01, 2.7070e-01, 1.9446e-01,
#         1.7093e-04, 2.1433e-01, 2.9364e-01, 8.1912e-05, 2.3055e-01, 2.6867e-01,
#         2.8621e-01, 2.4875e-01, 2.0698e-01, 2.5620e-01, 2.1747e-01, 1.9957e-01,
#         2.2657e-01, 1.7077e-01, 1.4534e-01, 1.3392e-01, 1.6159e-01, 2.3612e-01,
#         9.8732e-04, 1.8040e-01, 2.3661e-01, 2.2250e-01, 2.8711e-01, 2.0275e-01,
#         1.2885e-01, 2.1602e-01, 2.5332e-01, 2.5657e-01, 1.5005e-01, 1.0680e-03,
#         2.1013e-01, 1.6658e-01, 2.4858e-01, 1.6797e-01, 2.0883e-01, 2.7118e-01,
#         3.5742e-01, 1.8273e-01, 1.5682e-01, 2.7625e-01, 2.0309e-01, 2.1628e-04,
#         1.9436e-01, 2.7737e-01, 1.9138e-01, 1.6906e-01, 1.7067e-04, 2.3255e-01,
#         2.1952e-01, 1.4779e-01, 2.0860e-01, 1.6292e-01, 1.7702e-01, 1.4956e-02,
#         2.0300e-04, 1.6940e-01, 1.8219e-01, 2.2072e-01, 2.6930e-01, 1.8680e-01,
#         2.1171e-01, 3.5587e-01, 1.6822e-01, 1.7195e-01, 1.7586e-01, 1.6983e-01,
#         2.3750e-01, 2.1142e-01, 2.5923e-01, 2.4312e-01, 1.0692e-02, 1.7364e-01,
#         1.5507e-01, 2.5441e-01, 2.1545e-01, 1.9865e-01, 2.1936e-01, 1.6226e-01,
#         1.9321e-01, 1.4806e-01, 1.8825e-01, 2.5966e-01, 1.7545e-01, 1.8617e-01,
#         2.7332e-01, 1.2151e-01, 1.4041e-01, 2.6648e-01, 1.6817e-01, 2.8912e-01,
#         2.1808e-01, 2.0770e-01, 1.0715e-04, 3.6360e-04, 2.6575e-01, 2.0018e-01,
#         1.8982e-03, 1.1856e-04, 6.1499e-04, 2.1432e-01, 2.1902e-01, 1.5516e-01,
#         2.7962e-01, 2.1624e-01, 2.0063e-01, 2.0949e-01, 1.9082e-01, 1.3145e-01,
#         2.1579e-01, 2.2146e-01, 2.8364e-01, 1.6351e-01, 1.7482e-01, 2.3657e-01,
#         1.3843e-01, 2.6057e-01, 1.9642e-01, 2.6127e-01, 2.2012e-01, 1.5680e-01,
#         2.3104e-01, 2.0528e-01, 1.7397e-01, 2.9666e-01, 2.5559e-01, 2.0779e-01,
#         2.0817e-01, 2.0041e-01, 2.3009e-01, 2.8768e-01, 2.4307e-01, 2.5600e-01,
#         1.3137e-04, 1.6867e-01, 3.0547e-01, 5.9902e-04, 4.2951e-04, 2.7003e-01,
#         1.9461e-01, 3.0525e-01, 2.8071e-01, 2.4031e-01],
#        grad_fn=<SelectBackward0>)

# %%
radial_out2 = model.gaussian(malwares, model.centers, model.sigmas)

# %%
radial_out2[0]
# Out:
# tensor([3.3368e-01, 3.2373e-01, 2.9176e-01, 3.0106e-01, 3.9283e-01, 4.0723e-01,
#         2.8488e-01, 2.5151e-01, 3.0302e-01, 1.5371e-01, 4.0052e-01, 1.8218e-01,
#         1.8946e-01, 2.1879e-01, 2.1894e-01, 6.8597e-02, 1.9441e-01, 1.8159e-01,
#         3.9847e-01, 3.3350e-01, 2.6497e-01, 1.5123e-04, 2.5393e-01, 2.9485e-01,
#         4.1260e-01, 3.9113e-01, 1.1930e-01, 2.9893e-01, 1.2182e-02, 2.9365e-01,
#         3.3192e-01, 3.6363e-01, 2.1491e-01, 1.8752e-01, 3.6166e-01, 3.5482e-01,
#         3.2138e-01, 2.8950e-01, 2.8605e-01, 3.7667e-01, 2.5729e-01, 3.4933e-01,
#         2.9159e-01, 2.6463e-01, 2.9322e-01, 1.4583e-04, 3.8189e-01, 2.3029e-01,
#         1.1575e-01, 1.1340e-01, 3.2974e-01, 1.3111e-01, 1.6774e-01, 3.6475e-01,
#         2.4145e-01, 2.9452e-01, 2.1786e-01, 8.7196e-02, 3.3051e-01, 1.5335e-01,
#         3.3743e-01, 2.1316e-01, 5.3965e-02, 1.0683e-01, 3.7319e-01, 6.0739e-02,
#         2.7882e-01, 3.1340e-01, 1.6175e-04, 2.3864e-01, 1.9310e-01, 2.4613e-01,
#         3.5081e-01, 2.5574e-01, 2.4149e-01, 3.7072e-01, 2.0998e-01, 3.9420e-01,
#         1.5586e-01, 1.6636e-01, 7.3051e-02, 3.2172e-04, 3.0214e-01, 2.0276e-01,
#         1.9467e-01, 2.9892e-01, 2.6451e-01, 3.9581e-01, 1.2187e-04, 1.6178e-04,
#         1.3260e-01, 4.0071e-01, 2.5037e-01, 3.6221e-01, 3.7776e-01, 2.2136e-01,
#         2.4459e-01, 2.2675e-01, 4.3379e-02, 1.8729e-01, 3.6588e-01, 1.8727e-04,
#         2.8078e-01, 1.3652e-04, 2.0519e-01, 2.3279e-01, 2.0451e-01, 1.3178e-04,
#         3.1025e-01, 4.0065e-04, 1.3569e-01, 6.5734e-02, 1.8773e-01, 1.9343e-01,
#         9.9537e-02, 2.9712e-01, 3.1794e-01, 2.2033e-01, 2.5499e-01, 1.8891e-01,
#         3.0989e-01, 2.6841e-01, 1.9877e-01, 3.0184e-01, 2.3884e-01, 1.8272e-01,
#         1.3909e-01, 2.0786e-01, 3.5202e-01, 2.5313e-01, 5.6637e-03, 1.5215e-01,
#         2.9303e-01, 2.9851e-01, 3.8005e-01, 3.4204e-01, 3.1593e-01, 1.5541e-01,
#         3.0484e-01, 2.2794e-01, 2.1249e-01, 2.5847e-01, 3.4152e-01, 2.3482e-01,
#         2.7228e-01, 2.9834e-01, 2.9194e-01, 3.6269e-01, 3.3255e-01, 1.7158e-01,
#         1.1428e-01, 3.2242e-01, 2.2249e-01, 2.7100e-01, 3.8307e-01, 3.2965e-01,
#         2.4319e-01, 1.7497e-01, 1.0776e-01, 1.4818e-01, 3.3276e-01, 1.9093e-01,
#         3.4395e-01, 2.6058e-01, 2.5710e-01, 3.2104e-01, 3.0315e-01, 3.7722e-01,
#         2.5694e-01, 3.7551e-01, 3.7002e-01, 2.1982e-01, 2.6835e-01, 3.0787e-01,
#         2.3288e-01, 2.9623e-04, 3.0271e-01, 3.7568e-01, 1.9563e-01, 3.1242e-01,
#         2.3535e-01, 1.8627e-01, 4.1350e-01, 2.8015e-01, 2.1107e-01, 2.9283e-01,
#         2.8070e-01, 3.8848e-04, 3.2952e-01, 2.9790e-01, 2.2648e-01, 3.9571e-04,
#         3.9371e-01, 1.7284e-01, 2.5885e-01, 6.4051e-02, 2.0099e-01, 2.0002e-01,
#         3.0726e-01, 3.6200e-01, 2.5545e-01, 3.6329e-01, 2.1105e-01, 2.3860e-01,
#         1.9151e-01, 9.2958e-02, 2.2213e-01, 3.5573e-01, 1.2314e-01, 1.2695e-01,
#         3.4754e-01, 1.8237e-04, 1.7430e-01, 9.7726e-03, 3.9053e-01, 2.0386e-01,
#         1.5794e-01, 2.8974e-01, 2.6628e-01, 3.8864e-01, 2.7603e-01, 3.6067e-01,
#         2.0303e-04, 2.8110e-01, 2.9131e-01, 2.8187e-01, 7.4189e-02, 3.3549e-01,
#         3.5790e-01, 2.3283e-01, 2.1276e-01, 2.1924e-01, 1.4842e-01, 3.1952e-01,
#         2.1921e-01, 3.1203e-01, 1.6936e-01, 3.1645e-01, 6.2475e-02, 3.2004e-01,
#         3.1095e-01, 2.2825e-01, 1.5790e-04, 2.5674e-01, 1.6951e-01, 3.6092e-01,
#         9.7622e-02, 1.9819e-04, 2.0464e-01, 3.5806e-01, 2.8414e-01, 3.6745e-01,
#         3.5189e-01, 3.8401e-01, 2.0639e-01, 2.1716e-01, 2.6203e-01, 1.7914e-04,
#         3.8582e-01, 2.1418e-01, 8.0606e-02, 2.8899e-01, 1.5385e-01, 2.4173e-01,
#         2.1952e-01, 3.0117e-01, 3.2760e-01, 1.7830e-04, 2.2266e-01, 3.1524e-01,
#         3.4493e-01, 1.9902e-01, 2.4237e-01, 1.0935e-01, 1.3652e-04, 2.4949e-01,
#         3.1169e-01, 2.9663e-01, 3.6620e-02, 3.4723e-01, 1.4223e-01, 1.7220e-04,
#         3.4505e-01, 2.7941e-01, 2.5923e-01, 2.6008e-01, 2.1524e-01, 2.9894e-04,
#         3.5217e-01, 2.1952e-01, 1.9378e-01, 3.9897e-01, 3.8974e-01, 1.5205e-04,
#         1.3635e-01, 1.4996e-04, 3.7139e-01, 3.4155e-01, 3.2726e-01, 3.6318e-01,
#         3.3248e-01, 1.9515e-01, 2.1281e-01, 2.1830e-01, 3.2995e-01, 1.9553e-01,
#         3.0458e-01, 2.1310e-01, 2.1760e-01, 3.4798e-01, 2.6153e-01, 2.5418e-01,
#         2.3038e-01, 3.0169e-01, 2.1384e-01, 2.9066e-01, 1.8504e-01, 2.6135e-04,
#         3.8193e-01, 2.1447e-01, 1.0481e-01, 1.4660e-04, 2.1774e-01, 2.9996e-01,
#         3.3481e-01, 3.4757e-01, 2.4743e-01, 2.1645e-01, 2.9519e-01, 1.4255e-04,
#         3.2621e-01, 3.0525e-01, 9.7150e-02, 1.5285e-01, 2.9179e-01, 3.3714e-01,
#         5.5459e-04, 1.7716e-01, 3.0715e-01, 3.0616e-01, 2.5184e-01, 1.6687e-01,
#         4.0485e-01, 2.1775e-01, 2.2545e-01, 3.1657e-01, 1.9927e-01, 2.6949e-01,
#         3.7675e-01, 3.0316e-01, 2.0945e-01, 3.0288e-01, 2.1290e-01, 3.3522e-01,
#         2.6954e-01, 3.2836e-01, 3.8606e-01, 2.0546e-01, 2.1214e-01, 2.5927e-01,
#         2.2240e-01, 1.0931e-01, 2.0145e-01, 1.7486e-01, 1.6528e-01, 4.7060e-02,
#         2.9805e-01, 1.2223e-04, 2.8050e-01, 5.2344e-04, 3.0943e-01, 2.7420e-01,
#         2.9666e-01, 1.4348e-01, 2.4976e-01, 3.0841e-01, 3.5096e-01, 2.1786e-01,
#         2.8901e-01, 3.3313e-01, 3.4849e-01, 1.4267e-01, 3.8195e-01, 3.9153e-01,
#         2.0038e-01, 2.3179e-01, 2.9990e-01, 4.1302e-01, 2.1313e-01, 2.4263e-01,
#         3.1244e-01, 3.6919e-01, 3.2618e-01, 2.1156e-01, 1.2575e-01, 2.4795e-01,
#         1.4432e-01, 2.3448e-01, 9.8079e-02, 2.7649e-01, 3.6351e-01, 2.2272e-01,
#         2.6881e-01, 3.6781e-01, 3.3966e-01, 2.4852e-01, 3.2881e-01, 1.7263e-01,
#         2.7672e-01, 2.1568e-01, 2.5562e-01, 2.8461e-01, 3.8956e-01, 1.2156e-04,
#         2.9312e-01, 2.1134e-01, 2.6156e-01, 3.4835e-01, 3.0742e-01, 4.1453e-01,
#         3.6911e-01, 3.7233e-01, 2.5484e-01, 3.4174e-01, 1.2067e-01, 2.0792e-01,
#         2.9979e-01, 2.9571e-01, 1.4343e-03, 2.8103e-01, 1.7923e-01, 1.2934e-03,
#         2.9879e-01, 3.7210e-01, 2.5185e-01, 7.8199e-02, 3.4633e-01, 2.6225e-01,
#         8.5657e-02, 3.3178e-01, 3.8575e-01, 2.5591e-01, 3.4940e-01, 2.5461e-01,
#         3.6949e-01, 5.2328e-02, 1.2567e-03, 4.6174e-02, 2.2776e-01, 3.1870e-01,
#         3.2002e-04, 3.7689e-01, 1.4526e-01, 1.4539e-01, 2.1407e-01, 1.5033e-04,
#         3.2176e-01, 2.8713e-01, 3.2170e-01, 2.5678e-01, 9.6131e-02, 3.3754e-01,
#         2.5906e-01, 2.5037e-01, 2.4324e-01, 9.1733e-04, 8.6500e-02, 3.0286e-01,
#         2.9958e-01, 3.0815e-01, 4.2490e-01, 2.0396e-01, 1.7709e-01, 3.1461e-01,
#         3.8335e-01, 1.9529e-01, 2.2465e-01, 2.0366e-01, 3.8033e-01, 4.1593e-02,
#         3.4924e-01, 2.0054e-01, 1.7681e-01, 2.8451e-01, 2.1637e-01, 2.6165e-01,
#         3.1461e-01, 9.3575e-04, 2.3151e-01, 1.8343e-01, 3.5270e-01, 2.8905e-01,
#         2.7822e-01, 2.4464e-01, 2.2416e-01, 2.0529e-01, 3.1208e-01, 2.9778e-01,
#         2.7388e-01, 3.2399e-01, 2.6730e-01, 3.9745e-01, 1.7516e-01, 3.2868e-01,
#         3.0178e-01, 3.0335e-01, 3.6664e-01, 2.4964e-01, 1.8372e-01, 3.5457e-01,
#         1.3897e-01, 1.1811e-04, 2.7849e-01, 3.2121e-01, 3.0197e-01, 3.3387e-01,
#         9.3635e-02, 2.0218e-01, 3.7671e-01, 3.0248e-01, 3.6259e-01, 1.7265e-04,
#         2.7880e-01, 2.6018e-01, 3.9190e-01, 2.2025e-01, 3.8321e-01, 2.9948e-01,
#         2.9202e-01, 1.8891e-01, 1.8474e-01, 2.3818e-01, 3.0478e-01, 2.4444e-01,
#         2.0041e-01, 2.5514e-01, 3.8623e-01, 3.2852e-01, 1.3500e-01, 1.1584e-01,
#         9.0659e-02, 3.4570e-01, 2.7988e-01, 3.4476e-01, 3.2237e-01, 1.8978e-01,
#         1.7513e-01, 3.6072e-01, 1.8390e-01, 3.6965e-01, 2.9139e-02, 2.3662e-01,
#         3.5737e-01, 2.3052e-01, 3.4616e-01, 1.7533e-01, 3.3676e-01, 7.8703e-02,
#         3.1614e-01, 9.5354e-03, 3.3081e-01, 2.6225e-04, 1.9782e-01, 3.9462e-01,
#         2.3277e-01, 3.3912e-01, 2.1771e-01, 3.3267e-01, 2.3959e-01, 1.2463e-01,
#         1.4865e-04, 1.5372e-02, 3.4949e-04, 3.2851e-01, 2.9140e-01, 1.1125e-01,
#         3.0047e-01, 3.4948e-01, 1.3703e-01, 2.7312e-01, 2.1003e-01, 2.5448e-01,
#         1.7436e-01, 3.5629e-01, 1.4714e-01, 1.5742e-01, 2.3600e-01, 1.8957e-01,
#         2.5482e-01, 2.6783e-01, 3.5282e-01, 2.1442e-01, 1.9356e-01, 3.0123e-01,
#         2.4238e-01, 1.7171e-01, 2.2568e-01, 1.2568e-01, 1.6787e-01, 2.2484e-01,
#         1.0242e-01, 1.2925e-01, 1.8778e-01, 2.6131e-01, 5.1790e-02, 1.2025e-04,
#         2.3908e-01, 1.7276e-02, 3.5775e-01, 1.7542e-01, 2.2461e-01, 1.0576e-01,
#         2.5920e-01, 1.5574e-01, 3.0835e-01, 2.7900e-01, 1.1559e-01, 2.1601e-01,
#         2.3522e-01, 2.1735e-01, 2.7769e-01, 3.1985e-04, 3.3729e-01, 1.9744e-01,
#         3.9255e-01, 3.2059e-01, 1.2260e-01, 3.0950e-01, 3.1063e-01, 3.5456e-04,
#         3.4878e-01, 2.4205e-01, 1.9156e-01, 2.7192e-01, 6.8729e-02, 1.9268e-01,
#         1.1471e-01, 3.6639e-01, 1.0710e-01, 2.2254e-01, 1.0137e-01, 1.5390e-01,
#         4.1358e-01, 2.0724e-01, 2.5372e-01, 2.5184e-01, 3.8490e-01, 2.0357e-01,
#         2.0211e-01, 1.1271e-01, 3.3713e-01, 2.9916e-01, 1.9611e-01, 3.0995e-01,
#         2.4426e-01, 3.1298e-01, 1.4703e-01, 3.0756e-01, 2.1107e-01, 2.1161e-01,
#         1.2723e-01, 2.3856e-01, 2.4217e-01, 2.9865e-01, 1.6705e-01, 2.1844e-01,
#         2.8273e-01, 1.7304e-01, 2.5785e-01, 2.9694e-01, 2.1814e-01, 3.2596e-01,
#         6.0574e-04, 2.2287e-01, 2.6603e-01, 2.5516e-03, 1.9059e-01, 2.3927e-01,
#         1.0808e-01, 3.8781e-01, 1.6783e-01, 2.1174e-01, 3.1196e-01, 3.0202e-01,
#         2.4595e-01, 2.7825e-01, 2.1324e-01, 1.6384e-01, 2.3509e-01, 2.4655e-01,
#         1.1688e-01, 2.2844e-01, 1.5080e-02, 2.5887e-01, 2.7002e-01, 1.1186e-01,
#         1.3500e-01, 2.0266e-01, 2.6515e-01, 2.6482e-01, 1.9731e-01, 1.4134e-01,
#         6.7179e-02, 4.0801e-01, 3.9284e-01, 1.8425e-01, 1.8974e-01, 3.0127e-01,
#         1.9444e-01, 8.9160e-02, 1.7233e-01, 2.8650e-01, 2.1038e-01, 2.0449e-01,
#         1.3910e-04, 8.7926e-02, 3.3317e-01, 3.8048e-01, 1.0571e-03, 3.5858e-01,
#         3.0434e-01, 1.7121e-01, 2.2624e-01, 5.0677e-02, 1.1884e-01, 1.7694e-01,
#         1.0756e-04, 1.9253e-01, 2.3152e-01, 1.6528e-01, 1.6927e-01, 1.8425e-01,
#         2.1284e-01, 3.7564e-04, 1.9221e-04, 1.9005e-01, 1.9350e-01, 2.9213e-01,
#         2.7628e-01, 5.9645e-02, 1.3048e-01, 4.6833e-04, 2.1819e-01, 2.0948e-01,
#         3.6174e-01, 3.8564e-01, 2.3152e-01, 1.8773e-01, 3.7948e-01, 3.3421e-01,
#         2.7762e-01, 1.7202e-04, 2.8268e-01, 1.6831e-01, 2.9344e-01, 3.4672e-01,
#         1.3432e-01, 3.0616e-01, 3.6810e-01, 2.2897e-01, 1.8442e-01, 1.8042e-01,
#         2.6776e-01, 2.9944e-01, 1.7720e-04, 2.3275e-01, 3.4636e-01, 1.5862e-01,
#         2.3261e-01, 2.2807e-01, 3.1406e-01, 1.8052e-01, 3.0625e-01, 3.6737e-01,
#         2.4214e-01, 1.8074e-01, 4.0122e-01, 2.7970e-01, 1.7093e-01, 1.5583e-01,
#         2.0406e-01, 2.1009e-01, 1.8853e-01, 2.8113e-01, 1.9137e-01, 1.9847e-01,
#         3.5577e-01, 1.0144e-01, 2.7102e-01, 2.5078e-01, 3.4372e-01, 2.1842e-01,
#         3.4355e-01, 7.2905e-03, 2.4135e-01, 1.7637e-01, 2.2982e-01, 2.6263e-01,
#         2.9302e-01, 2.1918e-01, 2.9362e-01, 1.4039e-01, 2.9451e-01, 2.7941e-01,
#         2.1673e-01, 3.8475e-01, 2.5644e-01, 2.0548e-01, 2.6189e-01, 2.9129e-01,
#         4.2147e-03, 1.6983e-01, 2.6272e-01, 3.3041e-01, 1.7536e-01, 3.7345e-01,
#         3.6605e-01, 2.4590e-01, 1.3947e-01, 3.6474e-01, 2.6378e-01, 3.5135e-01,
#         3.6520e-01, 1.8932e-01, 1.5573e-01, 3.7984e-01, 2.4405e-03, 2.1223e-01,
#         2.7238e-01, 2.0253e-01, 1.9311e-04, 2.5931e-01, 2.0635e-01, 1.5921e-01,
#         2.5262e-01, 2.5591e-01, 1.7441e-01, 2.4516e-01, 2.4507e-01, 1.0243e-01,
#         2.5762e-01, 2.8950e-01, 1.8843e-01, 1.6590e-01, 8.9434e-02, 2.2781e-01,
#         2.5596e-01, 3.0491e-01, 1.1480e-01, 1.9930e-01, 3.3474e-01, 2.4900e-01,
#         2.0385e-01, 1.5384e-01, 2.6486e-01, 2.4899e-01, 3.9916e-01, 2.5218e-01,
#         1.9778e-04, 3.0513e-01, 3.5620e-01, 1.2469e-04, 2.0939e-01, 2.4704e-01,
#         3.1145e-01, 2.6965e-01, 2.9639e-01, 3.2891e-01, 2.4631e-01, 2.4395e-01,
#         1.8470e-01, 2.6797e-01, 1.5830e-01, 1.7047e-01, 1.9800e-01, 3.0585e-01,
#         1.5580e-03, 2.5364e-01, 3.1311e-01, 3.6285e-01, 3.1664e-01, 2.2511e-01,
#         2.0155e-01, 2.4301e-01, 3.4729e-01, 2.6123e-01, 1.7942e-01, 1.0663e-03,
#         2.1484e-01, 2.6731e-01, 3.6278e-01, 2.4253e-01, 2.4769e-01, 2.3908e-01,
#         2.8284e-01, 2.4101e-01, 1.9474e-01, 2.1427e-01, 2.6315e-01, 2.6959e-04,
#         3.2970e-01, 3.4068e-01, 2.2914e-01, 1.8570e-01, 2.2043e-04, 4.0290e-01,
#         2.0369e-01, 1.4217e-01, 2.9117e-01, 2.6745e-01, 2.3589e-01, 2.0740e-02,
#         2.3710e-04, 2.4621e-01, 2.3390e-01, 2.9877e-01, 3.9170e-01, 2.8396e-01,
#         2.4014e-01, 2.9164e-01, 2.7086e-01, 3.2778e-01, 2.6935e-01, 2.1992e-01,
#         3.2405e-01, 3.4374e-01, 3.6270e-01, 2.8696e-01, 1.4861e-02, 1.9169e-01,
#         1.8360e-01, 3.7469e-01, 2.7441e-01, 2.6288e-01, 2.3973e-01, 1.9681e-01,
#         3.0749e-01, 2.1262e-01, 2.2181e-01, 3.1485e-01, 2.9583e-01, 2.9066e-01,
#         3.5267e-01, 1.8773e-01, 1.9566e-01, 3.6764e-01, 2.6162e-01, 3.4392e-01,
#         3.0165e-01, 2.2134e-01, 9.4548e-05, 5.5948e-04, 2.8271e-01, 2.5943e-01,
#         2.3608e-03, 1.8779e-04, 6.8988e-04, 2.3602e-01, 3.2400e-01, 1.9516e-01,
#         3.2905e-01, 2.0058e-01, 2.4584e-01, 2.2592e-01, 2.4196e-01, 1.6246e-01,
#         2.5982e-01, 2.6083e-01, 2.8720e-01, 2.7346e-01, 2.1494e-01, 2.0135e-01,
#         2.1681e-01, 3.4162e-01, 2.7722e-01, 3.8398e-01, 2.2173e-01, 2.2573e-01,
#         1.9494e-01, 3.1012e-01, 2.3627e-01, 3.5225e-01, 2.2837e-01, 2.6765e-01,
#         3.4571e-01, 3.1895e-01, 3.0306e-01, 2.2982e-01, 3.0145e-01, 3.1098e-01,
#         1.8020e-04, 2.2815e-01, 3.1132e-01, 5.9766e-04, 4.6408e-04, 2.8237e-01,
#         2.6861e-01, 2.7872e-01, 2.5584e-01, 3.2245e-01],
#        grad_fn=<SelectBackward0>)

# %%
model.centers.shape
# Out:
# torch.Size([1000, 10000])

# %%
import torch.nn.functional as F

# Assuming centers is a tensor of shape [1000, 10000]
centers = model.centers

# Normalize the centers
centers_normalized = F.normalize(centers, p=2, dim=1)

# Compute the pairwise cosine similarity
pairwise_similarity = torch.matmul(centers_normalized, centers_normalized.T)

print("Pairwise similarity matrix shape:", pairwise_similarity.shape)
# Out:
# Pairwise similarity matrix shape: torch.Size([1000, 1000])

# %%
pairwise_similarity
# Out:
# tensor([[ 1.0000, -0.5264, -0.4279,  ..., -0.3901, -0.3136,  0.8498],
#         [-0.5264,  1.0000,  0.8905,  ...,  0.8698,  0.8534, -0.5546],
#         [-0.4279,  0.8905,  1.0000,  ...,  0.9153,  0.9022, -0.5060],
#         ...,
#         [-0.3901,  0.8698,  0.9153,  ...,  1.0000,  0.9077, -0.5077],
#         [-0.3136,  0.8534,  0.9022,  ...,  0.9077,  1.0000, -0.4081],
#         [ 0.8498, -0.5546, -0.5060,  ..., -0.5077, -0.4081,  1.0000]],
#        grad_fn=<MmBackward0>)

# %%
(pairwise_similarity>0.7).sum()
# Out:
# tensor(270714)

# %%
(pairwise_similarity<-0.7).sum()
# Out:
# tensor(5576)

# %%
results = (pairwise_similarity[0]>0.7)

# Get the indices where results is True
indices = torch.nonzero(results).squeeze()

print("Indices where results is True:", indices.tolist())
# Out:
# Indices where results is True: [0, 8, 11, 13, 16, 17, 18, 20, 22, 23, 24, 25, 29, 30, 33, 34, 35, 37, 38, 42, 48, 50, 54, 56, 61, 64, 65, 69, 73, 79, 84, 85, 86, 90, 100, 102, 105, 108, 115, 116, 119, 120, 123, 131, 132, 140, 144, 145, 154, 161, 162, 163, 165, 166, 173, 182, 185, 186, 188, 192, 193, 196, 197, 198, 201, 204, 206, 210, 214, 216, 217, 218, 219, 223, 225, 227, 229, 230, 237, 239, 240, 241, 245, 248, 251, 253, 256, 259, 262, 263, 264, 265, 266, 268, 269, 272, 275, 282, 283, 288, 289, 290, 291, 296, 298, 300, 303, 304, 309, 311, 312, 319, 326, 331, 335, 337, 340, 342, 350, 354, 355, 358, 359, 363, 366, 371, 372, 374, 376, 380, 383, 384, 386, 387, 388, 390, 397, 406, 408, 409, 415, 417, 419, 420, 421, 423, 425, 429, 432, 436, 440, 451, 457, 461, 462, 469, 470, 475, 480, 482, 483, 486, 488, 489, 492, 493, 494, 496, 497, 507, 508, 514, 518, 533, 536, 537, 545, 546, 547, 549, 553, 558, 562, 565, 568, 573, 576, 579, 583, 585, 588, 593, 594, 595, 601, 606, 614, 617, 622, 625, 626, 630, 642, 644, 645, 648, 663, 669, 671, 673, 674, 677, 682, 683, 684, 686, 688, 691, 698, 703, 704, 706, 707, 710, 711, 716, 717, 719, 720, 728, 731, 735, 738, 746, 747, 748, 750, 752, 753, 754, 757, 761, 762, 768, 769, 771, 774, 776, 777, 778, 781, 783, 785, 786, 792, 795, 796, 797, 800, 802, 805, 809, 814, 817, 818, 820, 823, 833, 834, 837, 838, 840, 844, 845, 846, 847, 849, 851, 854, 857, 862, 866, 869, 871, 874, 877, 879, 884, 886, 889, 891, 895, 896, 900, 901, 902, 905, 907, 910, 913, 915, 917, 920, 922, 924, 925, 927, 929, 930, 931, 936, 937, 940, 941, 945, 946, 958, 959, 965, 970, 974, 977, 978, 979, 980, 984, 985, 986, 996, 999]

# %%
non_unique = set()
unique = []
for i in range(1000):

  if i not in non_unique:
    results = (pairwise_similarity[i] > 0.9)
    indices = torch.nonzero(results)

    for element in indices:
        non_unique.add(element.item())

    unique.append(i)

len(unique)
# Out:
# 487

# %%
non_unique = set()
unique = []
for i in range(1000):

  if i not in non_unique:
    results = (pairwise_similarity[i] > 0.85)
    indices = torch.nonzero(results)

    for element in indices:
        non_unique.add(element.item())

    unique.append(i)

len(unique)
# Out:
# 362
